# %%
import pandas as pd
import numpy as np
mydata = pd.read_excel('Dataset.xlsx')
mydata
# Out:
#     This data set is about ordering in Talabat application ,and we collect those vote for this question (is the delivery fee is expensive?)  \
# 0                                                  NaN
# 1                                                  NO.
# 2                                                    1
# 3                                                    2
# 4                                                    3
# ..                                                 ...
# 508                                                507
# 509                                                508
# 510                                                509
# 511                                                510
# 512                                                511
#
#          Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5
# 0               NaN        NaN        NaN        NaN        NaN
# 1              Name        Age     Gender       City       Vote
# ...
